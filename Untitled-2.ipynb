# %%
import os
os.environ["KERAS_BACKEND"] = "torch"
import keras
import torch
if torch.cuda.is_available():
    print('Notebook gebruikt windows GPU')
elif torch.mps.is_available():
    print('Notebook gebruikt apple GPU')
else:
    print('Notebook gebruikt CPU')
# Out:
# c:\Users\nalin\anaconda3\Anaconda\envs\BP3.4\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# Notebook gebruikt CPU
